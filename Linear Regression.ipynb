# %%
import pandas as pd
import matplotlib.pyplot as plt
from  sklearn.model_selection import train_test_split 
from  sklearn.linear_model import LinearRegression
import sklearn.metrics

# %%
data_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/concrete/compressive/Concrete_Data.xls"
df = pd.read_excel(data_url)

# %%
df
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  \
# 0                                         540.0
# 1                                         540.0
# 2                                         332.5
# 3                                         332.5
# 4                                         198.6
# ...                                         ...
# 1025                                      276.4
# 1026                                      322.2
# 1027                                      148.5
# 1028                                      159.1
# 1029                                      260.9
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                   0.0
# 1                                                   0.0
# 2                                                 142.5
# 3                                                 142.5
# 4                                                 132.4
# ...

# %%
df.columns
# Out:
# Index(['Cement (component 1)(kg in a m^3 mixture)',
#        'Blast Furnace Slag (component 2)(kg in a m^3 mixture)',
#        'Fly Ash (component 3)(kg in a m^3 mixture)',
#        'Water  (component 4)(kg in a m^3 mixture)',
#        'Superplasticizer (component 5)(kg in a m^3 mixture)',
#        'Coarse Aggregate  (component 6)(kg in a m^3 mixture)',
#        'Fine Aggregate (component 7)(kg in a m^3 mixture)', 'Age (day)',
#        'Concrete compressive strength(MPa, megapascals) '],
#       dtype='object')

# %%
for c in df.columns:
    df[c].plot(title = c)
    plt.show()

# %%
df.plot(kind = "density", subplots = True,layout =(5,2),sharex = False,figsize=(20,20))
plt.show()

# %%
X = df[df.columns[0:-1]] #excluding last column
y = df[df.columns[-1]]#last column

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
reg = LinearRegression().fit(X_train,y_train)

# %%
reg.score(X_train,y_train)
# Out:
# 0.6173224327608906

# %%
y_predicted = reg.predict(X_test)
y_predicted
# Out:
# array([27.63267195, 50.05795663, 41.78790078, 31.50562963, 51.02572243,
#        31.05705237, 23.67708086, 28.51396009, 36.47979948, 35.396705  ,
#        33.10380414, 37.00475653, 25.77871745, 32.93745197, 12.09086521,
#        22.42675726, 40.2400705 , 25.11491129, 35.28550786, 24.03097966,
#        52.16550841, 25.71865546, 54.23294713, 16.84501203, 40.43759599,
#        48.99226003, 37.44435942, 35.97867163, 34.14434458, 34.2094519 ,
#        54.76200504, 37.63446885, 47.45601566, 23.04736096, 18.50865356,
#        33.7002432 , 26.51189179, 35.38947844, 24.83736732, 19.87716939,
#        43.13819039, 50.22759402, 17.21460974, 31.07561103, 39.21355466,
#        37.81118097, 30.80742628, 24.42338261, 41.95463494, 23.05069587,
#        61.89627032, 35.54226548, 27.99426871, 18.42599089, 54.10456004,
#        51.36020267, 28.26572443, 31.14054276, 38.35386645, 34.01646685,
#        56.69415293, 34.40744628, 22.69545335, 25.78173063, 24.42017048,
# ...

# %% [markdown]
# ## evaluate the predictions

# %%
mean_square_error = sklearn.metrics.mean_squared_error(y_test,y_predicted)
print(mean_square_error)
# Out:
# 106.32611884127286

# %%
r2_score = sklearn.metrics.r2_score(y_test,y_predicted)
r2_score
# Out:
# 0.6030887797262472
